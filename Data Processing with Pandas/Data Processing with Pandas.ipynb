# %%
import pandas as pd

# %% [markdown]
# ### The Series Data Structure

# %%
students = ['Affan', 'Khalid', 'Umer']
pd.Series(students)
# Out:
# 0     Affan
# 1    Khalid
# 2      Umer
# dtype: object

# %%
numbers = [11, 15, 117]
pd.Series(numbers)
# Out:
# 0     11
# 1     15
# 2    117
# dtype: int64

# %%
students = ['Affan', 'Khalid', None]
pd.Series(students)
# Out:
# 0     Affan
# 1    Khalid
# 2      None
# dtype: object

# %%
numbers = [11, 15, None]
pd.Series(numbers)
# Out:
# 0    11.0
# 1    15.0
# 2     NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
student_scores = {'Affan': 'Data Analyst',
                 'Khalid': 'Data Science',
                 'Umer': 'ML'}
s = pd.Series(student_scores)
s
# Out:
# Affan     Data Analyst
# Khalid    Data Science
# Umer                ML
# dtype: object

# %%
s.index
# Out:
# Index(['Affan', 'Khalid', 'Umer'], dtype='object')

# %%
students = [('Affan','Khan'), ('Khalid','Khan'), ('Umer','Khan')]
pd.Series(students)
# Out:
# 0     (Affan, Khan)
# 1    (Khalid, Khan)
# 2      (Umer, Khan)
# dtype: object

# %%
s = pd.Series(['Data Analytics', 'Data Science', 'ML'], index=['Affan', 'Khalid', 'Umer'])
s
# Out:
# Affan     Data Analytics
# Khalid      Data Science
# Umer                  ML
# dtype: object

# %%
student_scores = {'Affan': 'Data Analyst',
                 'Khalid': 'Data Science',
                 'Umer': 'ML'}
s = pd.Series(student_scores, index=['Affan', 'Umer', 'Usman'])
s
# Out:
# Affan    Data Analyst
# Umer               ML
# Usman             NaN
# dtype: object

# %% [markdown]
# ### Quering a Series

# %%
student_classes = {'Affan': 'Data Analytics',
                 'Khalid': 'Data Science',
                 'Umer': 'ML',
                  'Usman': 'Web Development'}
s = pd.Series(student_classes)
s
# Out:
# Affan      Data Analytics
# Khalid       Data Science
# Umer                   ML
# Usman     Web Development
# dtype: object

# %%
s.iloc[3]
# Out:
# 'Web Development'

# %%
s.loc['Umer']
# Out:
# 'ML'

# %%
s[3]
# Out:
# 'Web Development'

# %%
s['Usman']
# Out:
# 'Web Development'

# %%
class_codes = {'99': 'Data Analytics',
                 '100': 'Data Science',
                 '101': 'ML',
                  '102': 'Web Development'}
s = pd.Series(class_codes)
s
# Out:
# 99      Data Analytics
# 100       Data Science
# 101                 ML
# 102    Web Development
# dtype: object

# %%
grades = pd.Series([90, 80, 70, 60])
total = 0
for grade in grades:
    total += grade
print(total/len(grades))
# Out:
# 75.0

# %%
# A Better Way
avg = np.sum(grades) / len(grades)
avg
# Out:
# 75.0

# %%
numbers = pd.Series(np.random.randint(0,1000,10000))
numbers.head()
# Out:
# 0    633
# 1    822
# 2    108
# 3    301
# 4     10
# dtype: int64

# %%
# %%timeit -n 100
total = 0
for n in numbers:
    total += n
    
total/len(numbers)
# Out:
# 2.58 ms ± 1.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# parallel computing
# vectorization

# %%
# %%timeit -n 100
total = np.sum(numbers)
total/len(numbers)
# Out:
# 130 µs ± 68.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
numbers.head()
# Out:
# 0    633
# 1    822
# 2    108
# 3    301
# 4     10
# dtype: int64

# %%
numbers += 2
numbers.head()
# Out:
# 0    635
# 1    824
# 2    110
# 3    303
# 4     12
# dtype: int64

# %%
# for label, value in numbers.iteritems():
#     numbers.at(label, value+2)
# numbers.head()

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
for label,value in s.iteritems():
    s.loc[label] = value+2
# Out:
# 87.5 ms ± 14.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
s+=2
# Out:
# 885 µs ± 338 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
s = pd.Series([1,2,3])
s.loc['History'] = 102
s
# Out:
# 0            1
# 1            2
# 2            3
# History    102
# dtype: int64

# %%
student_classes = pd.Series({'Affan': 'Data Analytics',
                 'Khalid': 'Data Science',
                 'Umer': 'ML',
                  'Usman': 'Web Development'})

# %%
ali_classes = pd.Series(['Data Mining', 'Deep Learning', 'Cyber Security'], index = ['Ali', 'Ali', 'Ali'])
ali_classes
# Out:
# Ali       Data Mining
# Ali     Deep Learning
# Ali    Cyber Security
# dtype: object

# %%
all_students_classes = student_classes.append(ali_classes)
all_students_classes
# Out:
# Affan      Data Analytics
# Khalid       Data Science
# Umer                   ML
# Usman     Web Development
# Ali           Data Mining
# Ali         Deep Learning
# Ali        Cyber Security
# dtype: object

# %%
student_classes
# Out:
# Affan      Data Analytics
# Khalid       Data Science
# Umer                   ML
# Usman     Web Development
# dtype: object

# %%
all_students_classes.loc['Ali']
# Out:
# Ali       Data Mining
# Ali     Deep Learning
# Ali    Cyber Security
# dtype: object

# %% [markdown]
# ### DataFrame Data Structure

# %%
record1 = pd.Series({'Name': 'Ali',
                     'Class': 'Physics',
                     'Score': '85'})
record2 = pd.Series({'Name': 'Usman',
                     'Class': 'Chemistry',
                     'Score': '75'})
record3 = pd.Series({'Name': 'Hamza',
                     'Class': 'Maths',
                     'Score': '80'})

# %%
df = pd.DataFrame([record1, record2, record3], index = ['school1', 'school2', 'school1'])
df.head()
# Out:
#           Name      Class Score
# school1    Ali    Physics    85
# school2  Usman  Chemistry    75
# school1  Hamza      Maths    80

# %%
df.loc['school2']
# Out:
# Name         Usman
# Class    Chemistry
# Score           75
# Name: school2, dtype: object

# %%
type(df.loc['school2'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc['school1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['school1', 'Name']
# Out:
# school1      Ali
# school1    Hamza
# Name: Name, dtype: object

# %%
df.T
# Out:
#        school1    school2 school1
# Name       Ali      Usman   Hamza
# Class  Physics  Chemistry   Maths
# Score       85         75      80

# %%
df.T.loc['Name']
# Out:
# school1      Ali
# school2    Usman
# school1    Hamza
# Name: Name, dtype: object

# %%
df['Name']
# Out:
# school1      Ali
# school2    Usman
# school1    Hamza
# Name: Name, dtype: object

# %%
# Following will give an error
# df.loc['Name']

# %%
df.loc['school1']['Name']
# Out:
# school1      Ali
# school1    Hamza
# Name: Name, dtype: object

# %%
print(type(df.loc['school1']))
print(type(df.loc['school1']['Name']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df.loc[:,['Name', 'Score']]
# Out:
#           Name Score
# school1    Ali    85
# school2  Usman    75
# school1  Hamza    80

# %%
df.drop('school1')
# Out:
#           Name      Class Score
# school2  Usman  Chemistry    75

# %%
copy_df = df.copy()
copy_df.drop("Name", inplace = True, axis = 1)
copy_df
# Out:
#              Class Score
# school1    Physics    85
# school2  Chemistry    75
# school1      Maths    80

# %%
del copy_df['Class']
copy_df
# Out:
#         Score
# school1    85
# school2    75
# school1    80

# %%
df['ClassRanking'] = None
df
# Out:
#           Name      Class Score ClassRanking
# school1    Ali    Physics    85         None
# school2  Usman  Chemistry    75         None
# school1  Hamza      Maths    80         None

# %% [markdown]
# ### DataFrame Indexing and Loading

# %%
# !cat Admission_Predict.csv
# Out:
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5
# 10,323,108,3,3.5,3,8.6,0,0.45
# 11,325,106,3,3.5,4,8.4,1,0.52
# 12,327,111,4,4,4.5,9,1,0.84
# 13,328,112,4,4,4.5,9.1,1,0.78
# 14,307,109,3,4,3,8,1,0.62
# 15,311,104,3,3.5,2,8.2,1,0.61
# 16,314,105,3,3.5,2.5,8.3,0,0.54
# 17,317,107,3,4,3,8.7,0,0.66
# 18,319,106,3,4,3,8,1,0.65
# 19,318,110,3,4,3,8.8,0,0.63
# 20,303,102,3,3.5,3,8.5,0,0.62
# 21,312,107,3,3,2,7.9,1,0.64
# 22,325,114,4,3,2,8.4,0,0.7
# 23,328,116,5,5,5,9.5,1,0.94
# 24,334,119,5,5,4.5,9.7,1,0.95
# 25,336,119,5,4,3.5,9.8,1,0.97
# 26,340,120,5,4.5,4.5,9.6,1,0.94
# 27,322,109,5,4.5,3.5,8.8,0,0.76
# 28,298,98,2,1.5,2.5,7.5,1,0.44
# 29,295,93,1,2,2,7.2,0,0.46
# ...

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = pd.read_csv('Admission_Predict.csv', index_col = 0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
new_df = df.rename(columns={'GRE Score':'GRE Score', 'TOEFL Score':'TOEFL Score', 'University Rating':'University Rating',
                           'SOP':'Statement of Purpose', 'LOR':'Letter of Recommendation', 'CGPA':'CGPA', 'Research':'Research', 
                           'Chance of Admit':'Chance of Admit'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = new_df.rename(columns = {'LOR ': 'Letter of Recommendation'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of Recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1              0.92
# 2                                4.5  8.87         1              0.76
# 3                                3.5  8.00         1              0.72
# 4                                2.5  8.67         1              0.80
# 5                                3.0  8.21         0              0.65

# %%
new_df = new_df.rename(mapper=str.strip, axis='columns')
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of Recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 5                                3.0  8.21         0             0.65

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'Letter of Recommendation', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
 cols = list(df.columns)

# %%
cols = [x.lower().strip() for x in cols]
df.columns = cols
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %% [markdown]
#  ### Querying a DataFrame

# %%
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
admit_mask=df['chance of admit'] > 0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
df[df['chance of admit'] > 0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df['gre score'].head()
# Out:
# Serial No.
# 1    337
# 2    324
# 3    316
# 4    322
# 5    314
# Name: gre score, dtype: int64

# %%
df[['gre score','toefl score']].head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
df[df['gre score']>320].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
# 7                 321          109                  3  3.0  4.0  8.20
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 4                  1             0.80
# 6                  1             0.90
# 7                  1             0.75

# %%
(df['chance of admit'] > 0.7) & (df['chance of admit'] > 0.9)
# Out:
# Serial No.
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 396    False
# 397    False
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7) & df['chance of admit'].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %% [markdown]
# ### Indexing Dataframes

# %%
df['Serial Number'] = df.index

# %%
df = df.set_index('chance of admit')
df.head()
# Out:
#                  gre score  toefl score  university rating  sop  lor  cgpa  \
# chance of admit
# 0.92                   337          118                  4  4.5  4.5  9.65
# 0.76                   324          107                  4  4.0  4.5  8.87
# 0.72                   316          104                  3  3.0  3.5  8.00
# 0.80                   322          110                  3  3.5  2.5  8.67
# 0.65                   314          103                  2  2.0  3.0  8.21
#
#                  research  Serial Number
# chance of admit
# 0.92                    1              1
# 0.76                    1              2
# 0.72                    1              3
# 0.80                    1              4
# 0.65                    0              5

# %%
df = df.reset_index()
df.head()
# Out:
#    chance of admit  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0             0.92        337          118                  4  4.5  4.5  9.65
# 1             0.76        324          107                  4  4.0  4.5  8.87
# 2             0.72        316          104                  3  3.0  3.5  8.00
# 3             0.80        322          110                  3  3.5  2.5  8.67
# 4             0.65        314          103                  2  2.0  3.0  8.21
#
#    research  Serial Number
# 0         1              1
# 1         1              2
# 2         1              3
# 3         1              4
# 4         0              5

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df = df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
columns_to_keep = ['STNAME','CTYNAME','BIRTHS2010','BIRTHS2011','BIRTHS2012','BIRTHS2013',
                   'BIRTHS2014','BIRTHS2015','POPESTIMATE2010','POPESTIMATE2011',
                   'POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
# ...

# %%
df = df.set_index(['STNAME', 'CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Michigan', 'Washtenaw County']
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2010    345563
# POPESTIMATE2011    349048
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
df.loc[[ ('Michigan', 'Washtenaw County'), 
       ('Michigan', 'Wayne County'), ]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %% [markdown]
# ### Missing Values

# %%
df = pd.read_csv('class_grades.csv')
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
mask = df.isnull()
mask.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False

# %%
df.dropna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %%
df.fillna(0, inplace=True)
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17     0.00     63.15  48.89
# 3        7        0.00      0.00    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8        0.00    103.71    45.00     93.52  61.94
# 95       7        0.00     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df = pd.read_csv('log.csv')
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
df = df.set_index('time')
df = df.sort_index()
df.head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df = df.reset_index()
df = df.set_index(['time', 'user'])
df.head(10)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
df = pd.DataFrame({'A': [1,1,2,3,4],
                  'B': [3,6,3,8,9],
                  'C': ['a','b','c','d','e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1,100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace([1,3],[100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
df = pd.read_csv('log.csv')

# %%
df.replace(to_replace='.*.html$', value='webpage', regex=True)
# Out:
#           time    user    video  playback position paused  volume
# 0   1469974424  cheryl  webpage                  5  False    10.0
# 1   1469974454  cheryl  webpage                  6    NaN     NaN
# 2   1469974544  cheryl  webpage                  9    NaN     NaN
# 3   1469974574  cheryl  webpage                 10    NaN     NaN
# 4   1469977514     bob  webpage                  1    NaN     NaN
# 5   1469977544     bob  webpage                  1    NaN     NaN
# 6   1469977574     bob  webpage                  1    NaN     NaN
# 7   1469977604     bob  webpage                  1    NaN     NaN
# 8   1469974604  cheryl  webpage                 11    NaN     NaN
# 9   1469974694  cheryl  webpage                 14    NaN     NaN
# 10  1469974724  cheryl  webpage                 15    NaN     NaN
# 11  1469974454     sue  webpage                 24    NaN     NaN
# 12  1469974524     sue  webpage                 25    NaN     NaN
# ...

# %% [markdown]
# ### Manipulating DataFrame

# %%
df = pd.read_csv('presidents.csv')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
df['First'] = df['President']

# %%
df['First']=df['First'].replace("[ ].*", "", regex=True)
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First
# 0  67 years, 295 days  George
# 1  90 years, 247 days    John
# ...

# %%
del(df["First"])

# %%
def splitname(row):
    row['First']=row['President'].split()[0]
    row['Last']=row['President'].split()[-1]
    return row

# %%
df = df.apply(splitname, axis='columns')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
del(df["First"])
del(df["Last"])

# %%
pattern = "(^[\w]*)(?:.* )([\w]*$)"
df['President'].str.extract(pattern).head()
# Out:
#         0           1
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
pattern="(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"
names = df['President'].str.extract(pattern).head()
names
# Out:
#     First        Last
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
df['First']=names['First']
df['Last']=names['Last']
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
df['Born']=df['Born'].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")
df['Born'].head()
# Out:
# 0    Feb 22, 1732
# 1    Oct 30, 1735
# 2    Apr 13, 1743
# 3    Mar 16, 1751
# 4    Apr 28, 1758
# Name: Born, dtype: object

# %%
df['Born']=pd.to_datetime(df['Born'])
df['Born'].head()
# Out:
# 0   1732-02-22
# 1   1735-10-30
# 2   1743-04-13
# 3   1751-03-16
# 4   1758-04-28
# Name: Born, dtype: datetime64[ns]

# %% [markdown]
# ### Practice

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj2['California'] == None
# Out:
# False

# %%
d = {
    '1': 'Alice',
    '2': 'Bob',
    '3': 'Rita',
    '4': 'Molly',
    '5': 'Ryan'
}
S = pd.Series(d)

# %%
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
df.head()
# Out:
#    #          President       Born      Age atstart of presidency  \
# 0  1  George Washington 1732-02-22  57 years, 67 daysApr 30, 1789
# 1  2         John Adams 1735-10-30  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson 1743-04-13  57 years, 325 daysMar 4, 1801
# 3  4      James Madison 1751-03-16  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe 1758-04-28  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# ...

# %%
df.rename(mapper=lambda x: x.upper(), axis=1)
# Out:
#      #              PRESIDENT       BORN       AGE ATSTART OF PRESIDENCY  \
# 0    1      George Washington 1732-02-22   57 years, 67 daysApr 30, 1789
# 1    2             John Adams 1735-10-30   61 years, 125 daysMar 4, 1797
# 2    3       Thomas Jefferson 1743-04-13   57 years, 325 daysMar 4, 1801
# 3    4          James Madison 1751-03-16   57 years, 353 daysMar 4, 1809
# 4    5           James Monroe 1758-04-28   58 years, 310 daysMar 4, 1817
# 5    6      John Quincy Adams 1767-07-11   57 years, 236 daysMar 4, 1825
# 6    7         Andrew Jackson 1767-03-15   61 years, 354 daysMar 4, 1829
# 7    8       Martin Van Buren 1782-12-05    54 years, 89 daysMar 4, 1837
# 8    9    William H. Harrison 1773-02-09    68 years, 23 daysMar 4, 1841
# 9   10             John Tyler 1790-03-29     51 years, 6 daysApr 4, 1841
# 10  11          James K. Polk 1795-11-02   49 years, 122 daysMar 4, 1845
# 11  12         Zachary Taylor 1784-11-24   64 years, 100 daysMar 4, 1849
# ...

# %%
scores = {'gre score': [337,324,316,322,314],
          'toefl score': [118,107,104,110,103]}
df_new = pd.DataFrame(scores)

# %%
df_new
# Out:
#    gre score  toefl score
# 0        337          118
# 1        324          107
# 2        316          104
# 3        322          110
# 4        314          103

# %%
df_new.where(df_new['toefl score'] > 105).dropna()
# df_new.where(df_new['toefl score'] > 105)
# df_new[df_new['toefl score'] > 105]
# Out:
#    gre score  toefl score
# 0      337.0        118.0
# 1      324.0        107.0
# 3      322.0        110.0

# %%
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
df_new[(df_new['toefl score']>105) & (df_new['toefl score'] < 115)]
# Out:
#    gre score  toefl score
# 1        324          107
# 3        322          110

# %%
df_new[(df_new['toefl score'].isin(range(106,115)))]
# Out:
#    gre score  toefl score
# 1        324          107
# 3        322          110

# %%
(df_new['toefl score'] > 105) & (df_new['toefl score'] < 115)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: toefl score, dtype: bool
